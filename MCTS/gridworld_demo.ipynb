# %%
import gym
import gym_examples
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
from gridworld_demo import gridworld_demo

# %% [markdown]
# ### GridWorld Demo MCTS

# %%
gridworld_demo(ipynb=True)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 3]
#   agent: [2 2], visits: 500, value: 0.19
#     ↑ agent: [2 1], visits: 110, value: 0.19
#     → agent: [3 2], visits: 149, value: 0.24
#     ← agent: [1 2], visits: 130, value: 0.22
#     ↓ agent: [2 3], visits: 111, value: 0.19
# Selected action: →
# Obs: {'agent': array([3, 2]), 'target': array([0, 3])}
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 3]
#  → agent: [3 2], visits: 649, value: 0.16
#     → agent: [3 2], visits: 172, value: 0.18
#     ↑ agent: [2 1], visits: 216, value: 0.21
#     ↓ agent: [2 3], visits: 140, value: 0.15
#     ← agent: [1 2], visits: 120, value: 0.13
# Selected action: ↑
# Obs: {'agent': array([3, 1]), 'target': array([0, 3])}
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 3]
#  ↑ agent: [2 1], visits: 716, value: 0.15
#     → agent: [3 2], visits: 175, value: 0.16
#     ← agent: [1 2], visits: 180, value: 0.16
#     ↑ agent: [2 1], visits: 173, value: 0.16
#     ↓ agent: [2 3], visits: 187, value: 0.17
# Selected action: ↓
# Obs: {'agent': array([3, 2]), 'target': array([0, 3])}
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 3]
#  ↓ agent: [2 3], visits: 687, value: 0.15
#     → agent: [3 2], visits: 171, value: 0.17
#     ← agent: [1 2], visits: 170, value: 0.17
#     ↓ agent: [2 3], visits: 167, value: 0.16
#     ↑ agent: [2 1], visits: 178, value: 0.17
# Selected action: ↑
# Obs: {'agent': array([3, 1]), 'target': array([0, 3])}
# <PIL.Image.Image image mode=RGB size=150x150>
# MCTS Iteration 500/500
# Target: [0 3]
#  ↑ agent: [2 1], visits: 678, value: 0.13
#     → agent: [3 2], visits: 124, value: 0.09
#     ← agent: [2 2], visits: 171, value: 0.14
#     ↓ agent: [3 3], visits: 181, value: 0.15
#     ↑ agent: [3 1], visits: 201, value: 0.16
# Selected action: ↑
# Obs: {'agent': array([3, 0]), 'target': array([0, 3])}
# <PIL.Image.Image image mode=RGB size=150x150>
# Total reward: 0
